# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# # Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# # Create a list for holding the cities.
cities = []
# # Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

#     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
         cities.append(city)
# # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=52408bbcc448d1b2643b163e74928cc7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | inirida
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | yangmei
# Processing Record 6 of Set 1 | dicabisagan
# Processing Record 7 of Set 1 | pevek
# Processing Record 8 of Set 1 | gargzdai
# Processing Record 9 of Set 1 | indianola
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | hohhot
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | san pedro
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | omboue
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | dunkwa
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | ola
# Processing Record 23 of Set 1 | sola
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | diamantina
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | prieska
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | graham
# Processing Record 31 of Set 1 | martapura
# Processing Record 32 of Set 1 | katsuura
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | bonthe
# Processing Record 36 of Set 1 | sauce
# Processing Record 37 of Set 1 | praia
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | irece
# Processing Record 40 of Set 1 | olavarria
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | rocha
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | vinh
# Processing Record 49 of Set 1 | sur
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | acapulco
# Processing Record 3 of Set 2 | umm kaddadah
# Processing Record 4 of Set 2 | kalakamati
# Processing Record 5 of Set 2 | nishihara
# Processing Record 6 of Set 2 | cortez
# Processing Record 7 of Set 2 | mgandu
# Processing Record 8 of Set 2 | olafsvik
# Processing Record 9 of Set 2 | atar
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | hanzhong
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | marsa matruh
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | ballina
# Processing Record 17 of Set 2 | vostok
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | san borja
# Processing Record 20 of Set 2 | banjar
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-agapit
# Processing Record 24 of Set 2 | el alto
# Processing Record 25 of Set 2 | leningradskiy
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | iberia
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | ginda
# Processing Record 32 of Set 2 | sitka
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | saint-francois
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 2 | tual
# Processing Record 39 of Set 2 | kloulklubed
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | cedar lake
# Processing Record 43 of Set 2 | necochea
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | jacareacanga
# Processing Record 46 of Set 2 | pierre
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | los andes
# Processing Record 2 of Set 3 | port blair
# Processing Record 3 of Set 3 | jieshi
# Processing Record 4 of Set 3 | duz
# City not found. Skipping...
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | constitucion
# Processing Record 7 of Set 3 | pula
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | mahon
# Processing Record 11 of Set 3 | yatou
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | moron
# Processing Record 14 of Set 3 | yakeshi
# Processing Record 15 of Set 3 | kalmunai
# Processing Record 16 of Set 3 | acarau
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | sao joao da barra
# Processing Record 20 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 3 | marzuq
# Processing Record 22 of Set 3 | byron bay
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | dalen
# Processing Record 26 of Set 3 | saint anthony
# Processing Record 27 of Set 3 | kumluca
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | mana
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | ashcroft
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | nantucket
# Processing Record 37 of Set 3 | uchiza
# Processing Record 38 of Set 3 | newport
# Processing Record 39 of Set 3 | isangel
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | suntar
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | yerofey pavlovich
# Processing Record 48 of Set 3 | svetlogorsk
# Processing Record 49 of Set 3 | caronport
# Processing Record 50 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | sovetsk
# Processing Record 3 of Set 4 | alofi
# Processing Record 4 of Set 4 | camargo
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | rassvet
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | pasighat
# Processing Record 9 of Set 4 | san jose
# Processing Record 10 of Set 4 | maqrin
# City not found. Skipping...
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | majenang
# Processing Record 13 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 4 | khagaria
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | lamu
# Processing Record 17 of Set 4 | jatibonico
# Processing Record 18 of Set 4 | malanville
# Processing Record 19 of Set 4 | chingola
# Processing Record 20 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | encruzilhada do sul
# Processing Record 23 of Set 4 | harare
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | nassau
# Processing Record 26 of Set 4 | marawi
# Processing Record 27 of Set 4 | marienburg
# Processing Record 28 of Set 4 | date
# Processing Record 29 of Set 4 | krasnoarmeysk
# Processing Record 30 of Set 4 | sorong
# Processing Record 31 of Set 4 | ostrovnoy
# Processing Record 32 of Set 4 | koslan
# Processing Record 33 of Set 4 | ponta delgada
# Processing Record 34 of Set 4 | nelson bay
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | krasnoselkup
# Processing Record 38 of Set 4 | georgetown
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | pag
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | talaya
# Processing Record 43 of Set 4 | oktyabrskiy
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | kalawit
# Processing Record 46 of Set 4 | makakilo city
# Processing Record 47 of Set 4 | xiongshi
# City not found. Skipping...
# Processing Record 48 of Set 4 | razole
# Processing Record 49 of Set 4 | mvuma
# Processing Record 50 of Set 4 | longhua
# Processing Record 1 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 5 | bima
# Processing Record 3 of Set 5 | saint-joseph
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | homer
# Processing Record 6 of Set 5 | oksfjord
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | nhulunbuy
# Processing Record 9 of Set 5 | santa maria
# Processing Record 10 of Set 5 | vanavara
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | mount isa
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | chokurdakh
# Processing Record 15 of Set 5 | yerbogachen
# Processing Record 16 of Set 5 | camana
# Processing Record 17 of Set 5 | elat
# Processing Record 18 of Set 5 | dingle
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | vandoeuvre-les-nancy
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | wagar
# Processing Record 23 of Set 5 | kieta
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | rio gallegos
# Processing Record 26 of Set 5 | littleton
# Processing Record 27 of Set 5 | tuktoyaktuk
# Processing Record 28 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 5 | strezhevoy
# Processing Record 30 of Set 5 | yinchuan
# Processing Record 31 of Set 5 | juneau
# Processing Record 32 of Set 5 | luena
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | duku
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 37 of Set 5 | auras
# Processing Record 38 of Set 5 | isiro
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | moindou
# Processing Record 44 of Set 5 | deming
# Processing Record 45 of Set 5 | makamba
# Processing Record 46 of Set 5 | suicheng
# Processing Record 47 of Set 5 | zhanaozen
# Processing Record 48 of Set 5 | iturama
# Processing Record 49 of Set 5 | sindor
# Processing Record 50 of Set 5 | rio cuarto
# Processing Record 1 of Set 6 | kuito
# Processing Record 2 of Set 6 | yeppoon
# Processing Record 3 of Set 6 | manado
# Processing Record 4 of Set 6 | komsomolskiy
# Processing Record 5 of Set 6 | plettenberg bay
# Processing Record 6 of Set 6 | margate
# Processing Record 7 of Set 6 | yar-sale
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | new amsterdam
# Processing Record 10 of Set 6 | jamai
# Processing Record 11 of Set 6 | saskylakh
# Processing Record 12 of Set 6 | ambilobe
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | ushibuka
# Processing Record 15 of Set 6 | naryan-mar
# Processing Record 16 of Set 6 | coihaique
# Processing Record 17 of Set 6 | ciudad bolivar
# Processing Record 18 of Set 6 | ulaangom
# Processing Record 19 of Set 6 | krasnyy yar
# Processing Record 20 of Set 6 | salta
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | shankargarh
# Processing Record 23 of Set 6 | caravelas
# Processing Record 24 of Set 6 | marang
# Processing Record 25 of Set 6 | port-gentil
# Processing Record 26 of Set 6 | gushikawa
# Processing Record 27 of Set 6 | saint-louis
# Processing Record 28 of Set 6 | leh
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | krasnovishersk
# Processing Record 34 of Set 6 | roma
# Processing Record 35 of Set 6 | ixtapa
# Processing Record 36 of Set 6 | hovd
# Processing Record 37 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 6 | rockland
# Processing Record 39 of Set 6 | pine bluff
# Processing Record 40 of Set 6 | veraval
# Processing Record 41 of Set 6 | half moon bay
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | akdepe
# Processing Record 44 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | tezu
# Processing Record 47 of Set 6 | phuket
# Processing Record 48 of Set 6 | el fuerte
# Processing Record 49 of Set 6 | labuhan
# Processing Record 50 of Set 6 | bud
# Processing Record 1 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 2 of Set 7 | avarua
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | farafangana
# Processing Record 5 of Set 7 | milkovo
# Processing Record 6 of Set 7 | acambay
# Processing Record 7 of Set 7 | osorno
# Processing Record 8 of Set 7 | lagos
# Processing Record 9 of Set 7 | lebu
# Processing Record 10 of Set 7 | svetlaya
# Processing Record 11 of Set 7 | flinders
# Processing Record 12 of Set 7 | wadena
# Processing Record 13 of Set 7 | skelleftea
# Processing Record 14 of Set 7 | nampula
# Processing Record 15 of Set 7 | tiznit
# Processing Record 16 of Set 7 | stephenville
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | araxa
# Processing Record 19 of Set 7 | trat
# Processing Record 20 of Set 7 | mandalgovi
# Processing Record 21 of Set 7 | mlonggo
# Processing Record 22 of Set 7 | vestmanna
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | chandigarh
# Processing Record 25 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 7 | jinhua
# Processing Record 27 of Set 7 | koping
# Processing Record 28 of Set 7 | guangyuan
# Processing Record 29 of Set 7 | strelka
# Processing Record 30 of Set 7 | mareeba
# Processing Record 31 of Set 7 | georgiyevka
# Processing Record 32 of Set 7 | kashi
# Processing Record 33 of Set 7 | ojo caliente
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | alghero
# Processing Record 36 of Set 7 | copiapo
# Processing Record 37 of Set 7 | bijie
# Processing Record 38 of Set 7 | gayny
# Processing Record 39 of Set 7 | neka
# Processing Record 40 of Set 7 | ust-tsilma
# Processing Record 41 of Set 7 | baijiantan
# Processing Record 42 of Set 7 | boa vista
# Processing Record 43 of Set 7 | khatanga
# Processing Record 44 of Set 7 | bedesa
# Processing Record 45 of Set 7 | bubaque
# Processing Record 46 of Set 7 | gisborne
# Processing Record 47 of Set 7 | lata
# Processing Record 48 of Set 7 | sal rei
# Processing Record 49 of Set 7 | lazaro cardenas
# Processing Record 50 of Set 7 | puerto quijarro
# Processing Record 1 of Set 8 | saint-paul
# Processing Record 2 of Set 8 | fort nelson
# Processing Record 3 of Set 8 | san andres
# Processing Record 4 of Set 8 | coquimbo
# Processing Record 5 of Set 8 | wembley
# Processing Record 6 of Set 8 | myitkyina
# Processing Record 7 of Set 8 | hami
# Processing Record 8 of Set 8 | cognac
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | braganca
# Processing Record 11 of Set 8 | kissidougou
# Processing Record 12 of Set 8 | tocopilla
# Processing Record 13 of Set 8 | linfen
# Processing Record 14 of Set 8 | boueni
# Processing Record 15 of Set 8 | birjand
# Processing Record 16 of Set 8 | grao mogol
# Processing Record 17 of Set 8 | kijang
# Processing Record 18 of Set 8 | raudeberg
# Processing Record 19 of Set 8 | muzaffarabad
# Processing Record 20 of Set 8 | maumere
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | arroio grande
# Processing Record 23 of Set 8 | zyryanka
# Processing Record 24 of Set 8 | vila velha
# Processing Record 25 of Set 8 | riyadh
# Processing Record 26 of Set 8 | chara
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | kangaatsiaq
# Processing Record 29 of Set 8 | alekseyevka
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | nsanje
# Processing Record 32 of Set 8 | bilma
# Processing Record 33 of Set 8 | asfi
# Processing Record 34 of Set 8 | sobolevo
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | honningsvag
# Processing Record 37 of Set 8 | dreux
# Processing Record 38 of Set 8 | mazamari
# Processing Record 39 of Set 8 | yumen
# Processing Record 40 of Set 8 | payo
# Processing Record 41 of Set 8 | yongchang
# Processing Record 42 of Set 8 | gewane
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | tara
# Processing Record 45 of Set 8 | fort frances
# Processing Record 46 of Set 8 | beyneu
# Processing Record 47 of Set 8 | behbahan
# Processing Record 48 of Set 8 | finschhafen
# Processing Record 49 of Set 8 | morehead
# Processing Record 50 of Set 8 | oyek
# Processing Record 1 of Set 9 | shahrud
# Processing Record 2 of Set 9 | fairbanks
# Processing Record 3 of Set 9 | talnakh
# Processing Record 4 of Set 9 | meulaboh
# Processing Record 5 of Set 9 | severo-kurilsk
# Processing Record 6 of Set 9 | ambon
# Processing Record 7 of Set 9 | phan thiet
# Processing Record 8 of Set 9 | swan hill
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | bengkulu
# Processing Record 11 of Set 9 | talcher
# Processing Record 12 of Set 9 | itarema
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | weligama
# Processing Record 16 of Set 9 | tilichiki
# Processing Record 17 of Set 9 | tahta
# Processing Record 18 of Set 9 | mungeli
# Processing Record 19 of Set 9 | iquitos
# Processing Record 20 of Set 9 | kathmandu
# Processing Record 21 of Set 9 | champasak
# Processing Record 22 of Set 9 | tura
# Processing Record 23 of Set 9 | vanimo
# Processing Record 24 of Set 9 | alaca
# Processing Record 25 of Set 9 | agidel
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 9 | banda aceh
# Processing Record 29 of Set 9 | vaitape
# Processing Record 30 of Set 9 | general elizardo aquino
# Processing Record 31 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 9 | matara
# Processing Record 33 of Set 9 | aklavik
# Processing Record 34 of Set 9 | salinopolis
# Processing Record 35 of Set 9 | emerald
# Processing Record 36 of Set 9 | lokossa
# Processing Record 37 of Set 9 | vestmannaeyjar
# Processing Record 38 of Set 9 | sioux lookout
# Processing Record 39 of Set 9 | klaksvik
# Processing Record 40 of Set 9 | merauke
# Processing Record 41 of Set 9 | tommot
# Processing Record 42 of Set 9 | sovetskiy
# Processing Record 43 of Set 9 | potsdam
# Processing Record 44 of Set 9 | sawtell
# Processing Record 45 of Set 9 | verdun
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 48 of Set 9 | havre-saint-pierre
# Processing Record 49 of Set 9 | liberal
# Processing Record 50 of Set 9 | tarko-sale
# Processing Record 1 of Set 10 | porto nacional
# Processing Record 2 of Set 10 | kharp
# Processing Record 3 of Set 10 | demba
# Processing Record 4 of Set 10 | karasuk
# Processing Record 5 of Set 10 | road town
# Processing Record 6 of Set 10 | payson
# Processing Record 7 of Set 10 | katherine
# Processing Record 8 of Set 10 | presevo
# Processing Record 9 of Set 10 | ottumwa
# Processing Record 10 of Set 10 | daru
# Processing Record 11 of Set 10 | iranshahr
# Processing Record 12 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 10 | lambarene
# Processing Record 14 of Set 10 | noshiro
# Processing Record 15 of Set 10 | bijar
# Processing Record 16 of Set 10 | klamath falls
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | beloha
# Processing Record 19 of Set 10 | kachiry
# Processing Record 20 of Set 10 | port hedland
# Processing Record 21 of Set 10 | buraydah
# Processing Record 22 of Set 10 | bhimunipatnam
# Processing Record 23 of Set 10 | venado tuerto
# Processing Record 24 of Set 10 | novo aripuana
# Processing Record 25 of Set 10 | mayskiy
# Processing Record 26 of Set 10 | genhe
# Processing Record 27 of Set 10 | araioses
# Processing Record 28 of Set 10 | freeport
# Processing Record 29 of Set 10 | isabela
# Processing Record 30 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 10 | whitehorse
# Processing Record 32 of Set 10 | mecca
# Processing Record 33 of Set 10 | zhiryatino
# Processing Record 34 of Set 10 | orlik
# Processing Record 35 of Set 10 | sinjar
# Processing Record 36 of Set 10 | dunedin
# Processing Record 37 of Set 10 | san antero
# Processing Record 38 of Set 10 | lampazos de naranjo
# Processing Record 39 of Set 10 | olinda
# Processing Record 40 of Set 10 | manicore
# Processing Record 41 of Set 10 | thunder bay
# Processing Record 42 of Set 10 | port hardy
# Processing Record 43 of Set 10 | waingapu
# Processing Record 44 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 10 | dwarka
# Processing Record 46 of Set 10 | sao gabriel da cachoeira
# Processing Record 47 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 10 | ankola
# Processing Record 50 of Set 10 | trois-pistoles
# City not found. Skipping...
# Processing Record 1 of Set 11 | amarante do maranhao
# Processing Record 2 of Set 11 | hervey bay
# Processing Record 3 of Set 11 | tabou
# Processing Record 4 of Set 11 | klyuchi
# Processing Record 5 of Set 11 | two rivers
# Processing Record 6 of Set 11 | the valley
# Processing Record 7 of Set 11 | teguise
# Processing Record 8 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 11 | sterling
# Processing Record 10 of Set 11 | seoul
# Processing Record 11 of Set 11 | vao
# Processing Record 12 of Set 11 | pitsunda
# Processing Record 13 of Set 11 | puerto madero
# Processing Record 14 of Set 11 | maniitsoq
# Processing Record 15 of Set 11 | sulangan
# Processing Record 16 of Set 11 | izberbash
# Processing Record 17 of Set 11 | linhai
# Processing Record 18 of Set 11 | durban
# Processing Record 19 of Set 11 | college
# Processing Record 20 of Set 11 | ateptsevo
# Processing Record 21 of Set 11 | novogurovskiy
# Processing Record 22 of Set 11 | malindi
# Processing Record 23 of Set 11 | walvis bay
# Processing Record 24 of Set 11 | lermontovka
# Processing Record 25 of Set 11 | korla
# Processing Record 26 of Set 11 | viedma
# Processing Record 27 of Set 11 | aquidauana
# Processing Record 28 of Set 11 | broome
# Processing Record 29 of Set 11 | mehamn
# Processing Record 30 of Set 11 | whitianga
# Processing Record 31 of Set 11 | the pas
# Processing Record 32 of Set 11 | luderitz
# Processing Record 33 of Set 11 | sao jose da coroa grande
# Processing Record 34 of Set 11 | portland
# Processing Record 35 of Set 11 | handan
# Processing Record 36 of Set 11 | dudinka
# Processing Record 37 of Set 11 | mbandaka
# Processing Record 38 of Set 11 | le port
# Processing Record 39 of Set 11 | kayes
# Processing Record 40 of Set 11 | bonnyville
# Processing Record 41 of Set 11 | umm lajj
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | mastic beach
# Processing Record 44 of Set 11 | husavik
# Processing Record 45 of Set 11 | gazanjyk
# Processing Record 46 of Set 11 | itoman
# Processing Record 47 of Set 11 | gornozavodsk
# Processing Record 48 of Set 11 | ilebo
# Processing Record 49 of Set 11 | linjiang
# Processing Record 50 of Set 11 | san patricio
# Processing Record 1 of Set 12 | merritt
# Processing Record 2 of Set 12 | plzen
# Processing Record 3 of Set 12 | maracacume
# Processing Record 4 of Set 12 | kodinsk
# Processing Record 5 of Set 12 | puerto baquerizo moreno
# Processing Record 6 of Set 12 | barcelos
# Processing Record 7 of Set 12 | verkhnyaya inta
# Processing Record 8 of Set 12 | rio grande
# Processing Record 9 of Set 12 | jaisalmer
# Processing Record 10 of Set 12 | bereda
# Processing Record 11 of Set 12 | nadym
# Processing Record 12 of Set 12 | kaeo
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | nyagan
# Processing Record 15 of Set 12 | panaba
# Processing Record 16 of Set 12 | tallinn
# Processing Record 17 of Set 12 | zheleznodorozhnyy
# Processing Record 18 of Set 12 | benghazi
# Processing Record 19 of Set 12 | nakapiripirit
# Processing Record 20 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | prince rupert
# Processing Record 24 of Set 12 | sao raimundo das mangabeiras
# Processing Record 25 of Set 12 | jasper
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | clyde river
# Processing Record 28 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | kayerkan
# Processing Record 32 of Set 12 | porto santo
# Processing Record 33 of Set 12 | mardin
# Processing Record 34 of Set 12 | santiago del estero
# Processing Record 35 of Set 12 | kununurra
# Processing Record 36 of Set 12 | asyut
# Processing Record 37 of Set 12 | lakes entrance
# Processing Record 38 of Set 12 | canby
# Processing Record 39 of Set 12 | parasia
# Processing Record 40 of Set 12 | suzzara
# Processing Record 41 of Set 12 | yurimaguas
# Processing Record 42 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 12 | banepa
# Processing Record 44 of Set 12 | tuatapere
# Processing Record 45 of Set 12 | passo de camaragibe
# Processing Record 46 of Set 12 | ust-kut
# Processing Record 47 of Set 12 | akyab
# Processing Record 48 of Set 12 | maceio
# Processing Record 49 of Set 12 | ocampo
# Processing Record 50 of Set 12 | donskoye
# Processing Record 1 of Set 13 | luorong
# Processing Record 2 of Set 13 | oranjestad
# Processing Record 3 of Set 13 | karasjok
# Processing Record 4 of Set 13 | trapani
# Processing Record 5 of Set 13 | mezen
# Processing Record 6 of Set 13 | banapur
# Processing Record 7 of Set 13 | aksu
# Processing Record 8 of Set 13 | baracoa
# Processing Record 9 of Set 13 | itamaraca
# Processing Record 10 of Set 13 | amga
# Processing Record 11 of Set 13 | general pico
# Processing Record 12 of Set 13 | wabana
# Processing Record 13 of Set 13 | kamaishi
# Processing Record 14 of Set 13 | nushki
# Processing Record 15 of Set 13 | chapais
# Processing Record 16 of Set 13 | mirina
# City not found. Skipping...
# Processing Record 17 of Set 13 | flin flon
# Processing Record 18 of Set 13 | gat
# Processing Record 19 of Set 13 | sigerfjord
# City not found. Skipping...
# Processing Record 20 of Set 13 | kjollefjord
# Processing Record 21 of Set 13 | khani
# Processing Record 22 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 13 | kerzhenets
# City not found. Skipping...
# Processing Record 24 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | collie
# Processing Record 26 of Set 13 | bataipora
# Processing Record 27 of Set 13 | havoysund
# Processing Record 28 of Set 13 | chernyshevskiy
# Processing Record 29 of Set 13 | hokitika
# Processing Record 30 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 13 | likasi
# Processing Record 32 of Set 13 | ejutla de crespo
# Processing Record 33 of Set 13 | mora
# Processing Record 34 of Set 13 | dunn
# Processing Record 35 of Set 13 | shingu
# Processing Record 36 of Set 13 | suzu
# City not found. Skipping...
# Processing Record 37 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 38 of Set 13 | elizabeth city
# Processing Record 39 of Set 13 | yagodnoye
# Processing Record 40 of Set 13 | chardara
# Processing Record 41 of Set 13 | borogontsy
# Processing Record 42 of Set 13 | labuan
# Processing Record 43 of Set 13 | armizonskoye
# Processing Record 44 of Set 13 | hobyo
# Processing Record 45 of Set 13 | haines junction
# Processing Record 46 of Set 13 | angola
# Processing Record 47 of Set 13 | afsin
# Processing Record 48 of Set 13 | kamenka
# Processing Record 49 of Set 13 | talara
# Processing Record 50 of Set 13 | manta
# Processing Record 1 of Set 14 | north bend
# Processing Record 2 of Set 14 | glencoe
# Processing Record 3 of Set 14 | kwinana
# Processing Record 4 of Set 14 | gorontalo
# Processing Record 5 of Set 14 | oussouye
# Processing Record 6 of Set 14 | pitelino
# Processing Record 7 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 8 of Set 14 | tashla
# Processing Record 9 of Set 14 | cururupu
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | antananarivo
# Processing Record 12 of Set 14 | methoni
# Processing Record 13 of Set 14 | igarka
# Processing Record 14 of Set 14 | los llanos de aridane
# Processing Record 15 of Set 14 | nanning
# Processing Record 16 of Set 14 | angra
# City not found. Skipping...
# Processing Record 17 of Set 14 | makhinjauri
# Processing Record 18 of Set 14 | pedro ii
# Processing Record 19 of Set 14 | ushtobe
# Processing Record 20 of Set 14 | ahipara
# Processing Record 21 of Set 14 | marystown
# Processing Record 22 of Set 14 | san ramon de la nueva oran
# Processing Record 23 of Set 14 | lynn haven
# Processing Record 24 of Set 14 | finnsnes
# Processing Record 25 of Set 14 | avera
# Processing Record 26 of Set 14 | tolaga bay
# Processing Record 27 of Set 14 | naples
# Processing Record 28 of Set 14 | aksarka
# Processing Record 29 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 14 | great falls
# Processing Record 31 of Set 14 | konde
# Processing Record 32 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 14 | camapua
# Processing Record 34 of Set 14 | imbituba
# Processing Record 35 of Set 14 | vitim
# Processing Record 36 of Set 14 | baiyin
# Processing Record 37 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 38 of Set 14 | zhezkazgan
# Processing Record 39 of Set 14 | kirovo-chepetsk
# Processing Record 40 of Set 14 | auki
# Processing Record 41 of Set 14 | moussoro
# Processing Record 42 of Set 14 | rovnoye
# Processing Record 43 of Set 14 | baruun-urt
# Processing Record 44 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 14 | taltal
# Processing Record 46 of Set 14 | nuuk
# Processing Record 47 of Set 14 | catuday
# Processing Record 48 of Set 14 | iskandar
# Processing Record 49 of Set 14 | chester
# Processing Record 50 of Set 14 | carora
# Processing Record 1 of Set 15 | galati
# Processing Record 2 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 15 | jaragua
# Processing Record 4 of Set 15 | skibbereen
# Processing Record 5 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 15 | bambanglipuro
# Processing Record 7 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 8 of Set 15 | ordubad
# Processing Record 9 of Set 15 | hajiganj
# Processing Record 10 of Set 15 | praia da vitoria
# Processing Record 11 of Set 15 | valparaiso
# Processing Record 12 of Set 15 | richards bay
# Processing Record 13 of Set 15 | honiara
# Processing Record 14 of Set 15 | soe
# Processing Record 15 of Set 15 | mayumba
# Processing Record 16 of Set 15 | akdagmadeni
# Processing Record 17 of Set 15 | sombreffe
# Processing Record 18 of Set 15 | price
# Processing Record 19 of Set 15 | renqiu
# Processing Record 20 of Set 15 | togitsu
# Processing Record 21 of Set 15 | vlore
# Processing Record 22 of Set 15 | jumla
# Processing Record 23 of Set 15 | jalu
# Processing Record 24 of Set 15 | kinsale
# Processing Record 25 of Set 15 | marshalltown
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | quelimane
# Processing Record 28 of Set 15 | capreol
# Processing Record 29 of Set 15 | gidole
# Processing Record 30 of Set 15 | kasongo-lunda
# Processing Record 31 of Set 15 | nalbari
# Processing Record 32 of Set 15 | batemans bay
# Processing Record 33 of Set 15 | sinnamary
# Processing Record 34 of Set 15 | wahiawa
# Processing Record 35 of Set 15 | corinto
# Processing Record 36 of Set 15 | jatai
# Processing Record 37 of Set 15 | mangit
# Processing Record 38 of Set 15 | tukrah
# Processing Record 39 of Set 15 | santiago
# Processing Record 40 of Set 15 | gogrial
# Processing Record 41 of Set 15 | el retorno
# Processing Record 42 of Set 15 | wuzhou
# Processing Record 43 of Set 15 | porec
# Processing Record 44 of Set 15 | ancud
# Processing Record 45 of Set 15 | dolgoprudnyy
# Processing Record 46 of Set 15 | carutapera
# Processing Record 47 of Set 15 | aksaray
# Processing Record 48 of Set 15 | axim
# Processing Record 49 of Set 15 | yenagoa
# Processing Record 50 of Set 15 | edd
# Processing Record 1 of Set 16 | hargeysa
# Processing Record 2 of Set 16 | dawei
# Processing Record 3 of Set 16 | luau
# Processing Record 4 of Set 16 | hambantota
# Processing Record 5 of Set 16 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 16 | we
# City not found. Skipping...
# Processing Record 7 of Set 16 | gizo
# Processing Record 8 of Set 16 | binzhou
# Processing Record 9 of Set 16 | huanren
# Processing Record 10 of Set 16 | muhos
# Processing Record 11 of Set 16 | jinxi
# Processing Record 12 of Set 16 | sao luiz gonzaga
# Processing Record 13 of Set 16 | mattru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Date",
                    "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed"] 
# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Qaanaaq  77.4840  -69.3632     29.48        87         100       11.18
# 1         Nome  64.5011 -165.4064     26.67        93          40        5.75
# 2      Inirida   3.8653  -67.9239     90.90        54          97        2.55
# 3       Albany  42.6001  -73.9662     67.17        75          91        3.00
# 4      Yangmei  24.1023  112.5618     62.64        96         100        6.64
# 5  Dicabisagan  17.0818  122.4157     78.58        87          99        6.87
# 6        Pevek  69.7008  170.3133     22.06        91         100        6.55
# 7     Gargzdai  55.7128   21.4033     45.86        70           4        5.66
# 8    Indianola  41.3581  -93.5574     73.31        68         100        7.81
# 9        Bluff -46.6000  168.3333     53.80        70         100       12.71
#
#   Country                 Date
# 0      GL  2021-10-10 17:12:52
# 1      US  2021-10-10 17:12:52
# 2      CO  2021-10-10 17:12:53
# 3      US  2021-10-10 17:10:28
# 4      CN  2021-10-10 17:12:53
# 5      PH  2021-10-10 17:12:53
# 6      RU  2021-10-10 17:11:27
# 7      LT  2021-10-10 17:12:54
# 8      US  2021-10-10 17:12:54
# 9      NZ  2021-10-10 17:12:54

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
